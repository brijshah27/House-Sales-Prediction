# %%
#Pandas  and Numpy Library Imported from anaconda
import pandas as pd
import numpy as np

# %%
# reading a CSV file directly from folder, and store it in a pandas DataFrame:
# "read_csv" is a pandas function to read csv files from web or local device:

house_df=pd.read_csv("E:\Master of Science\SEM-4\CS4661\Project\kc_house_data.csv")

# %%
#  checking the dataset by printing every 10 lines:
house_df[0::10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 20     6300500875  20140514T000000   385000.0         4       1.75
# 30     8562750320  20141110T000000   580500.0         3       2.50
# 40     5547700270  20140715T000000   625000.0         4       2.50
# 50     5245600105  20140916T000000   228000.0         3       1.00
# 60     1516000055  20141210T000000   650000.0         3       2.25
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 80     5104520400  20141202T000000   390000.0         3       2.50
# 90     2791500270  20140522T000000   243500.0         4       2.50
# 100    1952200240  20140611T000000   850830.0         3       2.50
# 110    9545230140  20140725T000000   597750.0         4       2.50
# 120    7278700070  20150102T000000   660000.0         3       2.50
# ...

# %%
# Printing the size of datasets
house_df.shape
# Out:
# (21613, 21)

# %%
list(house_df)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
# converting Date column from string to date format
house_df['date']=pd.to_datetime(house_df['date'])

#converting date to numeric
#house_df['date']=pd.to_numeric(house_df['date'])
house_df['date']=(house_df['date'] - house_df['date'].min())  / np.timedelta64(1,'D')
house_df
# Out:
#                id   date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  164.0   221900.0         3       1.00         1180
# 1      6414100192  221.0   538000.0         3       2.25         2570
# 2      5631500400  299.0   180000.0         2       1.00          770
# 3      2487200875  221.0   604000.0         4       3.00         1960
# 4      1954400510  292.0   510000.0         3       2.00         1680
# 5      7237550310   10.0  1225000.0         4       4.50         5420
# 6      1321400060   56.0   257500.0         3       2.25         1715
# 7      2008000270  258.0   291850.0         3       1.50         1060
# 8      2414600126  348.0   229500.0         3       1.00         1780
# 9      3793500160  314.0   323000.0         3       2.50         1890
# 10     1736800520  336.0   662500.0         3       2.50         3560
# 11     9212900260   25.0   468000.0         2       1.00         1160
# ...

# %%
# Creating the Feature Matrix for House sale dataset:

# create a python list of feature names that would like to pick from the dataset:

feature_cols = ['id','date','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade','sqft_above',
                'sqft_basement','yr_built','yr_renovated','zipcode','lat','long','sqft_living15','sqft_lot15']

# use the above list to select the features from the original DataFrame
X =house_df[feature_cols]

# this is the original categorical labels (the latest revision of sklearn accepts non-numerical labels)
y =house_df['price']


# print the first 5 rows
print(X.head())

# print the first 5 rows
print(y.head())
# Out:
#            id   date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  164.0         3       1.00         1180      5650     1.0
# 1  6414100192  221.0         3       2.25         2570      7242     2.0
# 2  5631500400  299.0         2       1.00          770     10000     1.0
# 3  2487200875  221.0         4       3.00         1960      5000     1.0
# 4  1954400510  292.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# The following line will import LinearRegression "Class"

#from sklearn.preprocessing import normalize

#X=normalize(X, norm='max', axis=1, copy=True, return_norm=False)

#X

# %%
# The following line will import LinearRegression "Class"

from sklearn.linear_model import LinearRegression

# %%
# importing the method:
from sklearn.cross_validation import cross_val_score

# %%
# Applying 10-fold cross validation with "logistic regression" classifier:

# In the following line, "my_logreg" is instantiated as an "object" of LogisticRegression "class". 

my_linreg = LinearRegression()

mse_list = cross_val_score(my_linreg, X, y, cv=10, scoring='neg_mean_squared_error')

print(mse_list)
# Out:
# [ -4.39059074e+10  -4.76265911e+10  -3.59121402e+10  -5.05368254e+10
#   -3.48564143e+10  -3.61315163e+10  -3.52054047e+10  -3.82126561e+10
#   -4.03836801e+10  -4.51236354e+10]

# %%
# Notice that "cross_val_score" by default provides "negative" values for "mse" to clarify that mse is error.
# in order to calculate root mean square error (rmse), we have to make them positive!
mse_list_positive = -mse_list

# using numpy sqrt function to calculate rmse:
rmse_list = np.sqrt(mse_list_positive)
print(rmse_list)
# Out:
# [ 209537.3652605   218235.17384017  189504.98720581  224803.97102733
#   186698.72615237  190082.9194912   187631.03340888  195480.57733663
#   200956.91099198  212423.24591161]

# %%
# calculate the average RMSE as final result of cross validation:
print(rmse_list.mean())
# Out:
# 201535.491063
